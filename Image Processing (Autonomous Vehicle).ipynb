# %%
import numpy as np
import cv2 as cv

import matplotlib.pyplot as plt

# %%
data = np.load('Final_data.npy')

# %%
imgs = data[0]
steering = data[1]

# %%
imgs[0]
# Out:
# 'C:\\Users\\rmadh\\Desktop\\Jupyter Files\\Self Driving Car\\IMG\\center_2021_07_20_16_51_44_193.jpg'

# %%
def crop_img(path):
    img = cv.imread(path)
    crop = img[60:135,:,:]
    return crop

def bgr2yuv(crop):
    yuv = cv.cvtColor(crop,cv.COLOR_BGR2YUV)
    return yuv

# %%
crop = crop_img('C:\\Users\\rmadh\\Desktop\\Jupyter Files\\Self Driving Car\\IMG\\center_2021_07_20_16_51_44_193.jpg')
plt.imshow(crop)

# %%
yuv = bgr2yuv(crop)
plt.imshow(yuv)

# %%
plt.imshow(yuv)

# %%
img = cv.imread('C:\\Users\\rmadh\\Desktop\\Jupyter Files\\Self Driving Car\\IMG\\center_2021_07_20_16_51_44_193.jpg')

# %%
plt.imshow(np.uint8(img))

# %%
plt.imshow(np.uint8(img/2))

# %%
img = cv.imread('C:\\Users\\rmadh\\Desktop\\Jupyter Files\\Self Driving Car\\IMG\\center_2021_07_20_16_51_44_193.jpg')

brightness_cont = np.random.randint(1,4)
plt.imshow(np.uint8(img/brightness_cont))
